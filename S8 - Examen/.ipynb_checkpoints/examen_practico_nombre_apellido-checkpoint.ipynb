# %%
# Importamos librerias

# %% [markdown]
# # Importar datos y comprenderlos

# %% [markdown]
# # Preparar los datos

# %% [markdown]
# # Dividir los datos

# %% [markdown]
# # Evaluar modelos

# %% [markdown]
# # Ajustar hiperparámetros

# %% [markdown]
# # Evaluación final

# %% [markdown]
# # Conclusiones
